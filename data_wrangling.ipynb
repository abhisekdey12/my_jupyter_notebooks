# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/abhisek_damayanti/Documents/MyPythonCodes/AbhisekCodes/my_jupyter_notebooks/datasets/CHES2019V3.csv')
df.head()
# Out:
#    country  eastwest   party  party_id  eu_position  eu_position_sd  \
# 0        1       1.0      PS       102     6.083334        0.288675
# 1        1       1.0  SP/SPA       103     6.000000        0.426401
# 2        1       1.0   ECOLO       104     6.583334        0.514929
# 3        1       1.0  AGALEV       105     6.583334        0.514929
# 4        1       1.0  PRL/MR       106     6.500000        0.674200
#
#    eu_salience  eu_dissent   eu_blur  eu_cohesion  ...   regions  \
# 0     4.272728        2.75  2.166667        6.250  ...  6.000000
# 1     4.181818        2.50  1.714286        6.000  ...  5.333334
# 2     4.818182        2.50  1.428572        6.000  ...  6.166666
# 3     4.818182        2.50  1.285714        5.875  ...  6.083334
# 4     5.090909        2.00  1.714286        5.500  ...  6.416666
#
#    russian_interference  anti_islam_rhetoric  people_vs_elite  \
# 0              0.111111             2.111111         3.363636
# ...

# %%
df.isnull().mean()
# Out:
# country                  0.000000
# eastwest                 0.108303
# party                    0.003610
# party_id                 0.000000
# eu_position              0.000000
# eu_position_sd           0.000000
# eu_salience              0.000000
# eu_dissent               0.007220
# eu_blur                  0.003610
# eu_cohesion              0.108303
# eu_foreign               0.111913
# eu_intmark               0.108303
# eu_budgets               0.111913
# eu_asylum                0.111913
# lrgen                    0.000000
# lrecon                   0.000000
# lrecon_sd                0.000000
# lrecon_salience          0.000000
# lrecon_dissent           0.007220
# lrecon_blur              0.010830
# galtan                   0.000000
# galtan_sd                0.000000
# galtan_salience          0.000000
# galtan_dissent           0.028881
# galtan_blur              0.007220
# immigrate_policy         0.000000
# immigrate_salience       0.000000
# ...

# %%
df.shape
# Out:
# (277, 55)

# %%
for cols in df.columns:
    if df[cols].isnull().mean() > 0.5:
        df.drop(columns=[cols], inplace=True)

# %%
df.shape
# Out:
# (277, 52)
